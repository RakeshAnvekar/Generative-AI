# %%
## Manage a to do list

to_do_list=["Buy Groceires","Clean the houe","pay bills"]

## Adding some new task

to_do_list.append("Schedue the meeting")
to_do_list.append("go for a run")

## Remove a completed task

to_do_list.remove("Clean the houe")

if "pay bills" in to_do_list:
    print("Dont forgrt to pay the bill")
else:
    print("Paid bill")
print("To do list: =>")
for task in to_do_list:
    print(f"-{task}")
# Out:
# Dont forgrt to pay the bill
# To do list: =>
# Buy Groceires
# pay bills
# Schedue the meeting
# go for a run

# %%
## Organizing student grades

grades=[85,92,78,88]

grades.append(99)

##calculate the avg grade

average_grade=sum(grades)/len(grades)

print(f"The Average Grade: {average_grade}")

print(f"Heighest grade{max(grades)}")
