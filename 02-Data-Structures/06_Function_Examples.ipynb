# %%
## temperature conversion
def convert_temperature(temp,unit):
    """this function convert temp between celcius and fahrenheit"""
    if unit=='C':
        return temp * 9/5 +32 ## convert celcious to fahrenheit
    elif unit=='F':
        return (temp - 32)*5/9
    else: 
        return None

convert_temperature(77,'F')
# Out:
# 25.0

# %%
## Password Strengh checker
def is_strong_password(password):
    """this function checks if the password is strong or not"""
    if len(password)<8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any (char in '!@#$%^&*()_+=' for char in password):
        return False
    return True

print(is_strong_password("rakesSSh@123"))
# Out:
# True

# %%
## calcu;ate the total cost of the items in cart

cart=[

    {
        'name':'apple','price':0.5,'quntity':10
    },
     {
            'name':'orrange','price':0.7,'quntity':2
    },
    {
            'name':'rice','price':10,'quntity':3
    },
]

def calculate_total_cost(cartItems):
    """"""
    totalCost=0
    for item in cartItems:
        totalCost+=item["price"] * item["quntity"]
    return totalCost

print(calculate_total_cost(cart))
# Out:
# 36.4

# %%
## check the string palindrome or not

def factorial(n):
    if n==0:
        return 1
    else: 
        return n * factorial(n-1)


print(factorial(6))
# Out:
# 720

# %%
## afunction to read a file and count thhe frequency of each word

def count_worf_freqiency(fle_pah):
    word_count={}
    with open(fle_pah,'r') as file:
        for line in file:
            words=line.split()
            for word in words:
                word=word.lower()
                word_count[word]=word_count.get(word,0)+1
    return word_count


filePath="testFile.txt"
word_frequency=count_worf_freqiency(filePath)
print(word_frequency)
# Out:
# {'hi': 1, 'i': 1, 'am': 1, 'rakesh': 1, 'vinod': 1, 'anvekar': 1}
