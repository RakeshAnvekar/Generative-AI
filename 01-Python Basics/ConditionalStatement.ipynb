# %%
## If Statement
age = 20
if age >=20:
    print("eligible")
else:
    print("not eligible")
# Out:
# eligible

# %%
## If Else Statement
name="John"
if name=="John":
    print("Hello John")
else:
    print("Hello Stranger")
# Out:
# Hello John

# %%
## elif Statement
age=20
if age<20:
    print("not eligible")
elif age==20:
    print("eligible")
elif age>20:
    print("eligible")
else:
    print("not eligible")
# Out:
# eligible

# %%
## Nested If Statement
age=int(input("Enter your age: "))
nationality= str(input("Enter your nationality: "))
if age>=20:
    print("eligible")
    if nationality=="Indian":
        print("Eligible for Indian")

else:
    print("not eligible")
# Out:
# not eligible

# %%
## if the year is leap year or not

year=int(input("Enter the year: "))
if year %4==0:
    if year %100==0:
        if year %400==0:
            print(year, "is a leap year")
        else:
            print(year, "is not a leap year")
    else:
        print(year, "is a leap year")
else:
    print(year, "is not a leap year")
# Out:
# 2022 is not a leap year

# %%
## calcutor
firstNumber=int(input("Enter first number: "))
secondNumber=int(input("Enter second number: "))
operation=input("Enter operation (+, -, *, /): ")

if operation=="+":
    print(firstNumber+secondNumber)
elif operation=="-":    
    print(firstNumber-secondNumber)
elif operation=="*":
    print(firstNumber*secondNumber)
elif operation=="/":
    print(firstNumber/secondNumber)
else:
    print("Invalid operation")
# Out:
# 3

# %%
## determine  ticket prise based on the age of the person
