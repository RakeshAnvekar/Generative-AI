# %%
import math
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
from math import sqrt,pi
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np

np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *

# %%
from custom_Package.maths import add
add(1,2)
# Out:
# 3

# %%
from custom_Package import maths
maths.add(1,2)
# Out:
# 3
